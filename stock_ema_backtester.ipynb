# %% [markdown]
# <a href="https://colab.research.google.com/github/at9725/random-code/blob/main/stock_ema_backtester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime as dt
from pandas_datareader import data as pdr

# %%
stock = input("Enter a stock ticker symbol:  ")
print(stock)
# Out:
# Enter a stock ticker symbol:  MSFT
# MSFT

# %%
startyear = 2019
startmonth = 1
startday =1

start = dt.datetime(startyear,startmonth,startday)

now = dt.datetime.now()

df = yf.download(stock,start,now)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
emasUsed = [3,5,8,10,12,15,30,35,40,45,50,60]
for x in emasUsed:
  ema = x
  df["Ema_" + str(ema)] = round(df.iloc[:,4].ewm(span=ema, adjust = False).mean(),2)
print(df.tail())
# Out:
# Price            Close        High         Low        Open    Volume  \
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2025-01-13  417.190002  418.500000  412.290009  415.239990  17604800
# 2025-01-14  415.670013  419.739990  410.720001  417.809998  16935900
# 2025-01-15  426.309998  428.149994  418.269989  419.130005  19637800
# 2025-01-16  424.579987  429.489990  424.390015  428.700012  15300000
# 2025-01-17  429.029999  434.480011  428.170013  434.089996  26148000
#
# Price             Ema_3        Ema_5        Ema_8       Ema_10       Ema_12  \
# Ticker
# Date
# 2025-01-13  18012042.67  17858562.88  17859624.21  18009121.68  18206296.90
# 2025-01-14  17473971.33  17551008.59  17654352.17  17813990.47  18010851.22
# 2025-01-15  18555885.67  18246605.73  18095118.35  18145592.20  18261151.03
# 2025-01-16  16927942.83  17264403.82  17473980.94  17628211.80  17805589.33
# 2025-01-17  21537971.42  20225602.54  19401540.73  19177264.20  19089037.13
#
# ...

# %%
# numH = 0
# numC = 0

pos = 0
num = 0
percentchange = []


for i in df.index:
  cmin = min(df["Ema_3"][i],df["Ema_5"][i],df["Ema_8"][i],df["Ema_10"][i],df["Ema_12"][i],df["Ema_15"][i])
  cmax = max(df["Ema_30"][i],df["Ema_35"][i],df["Ema_40"][i],df["Ema_45"][i],df["Ema_50"][i],df["Ema_60"][i])

  close = df.loc[i,"Close"]

  if cmin > cmax:
    print("Red White Blue")
    if pos == 0:
      bp = close
      pos =1
      print("Buying now at " + str(bp))
  elif cmin < cmax:
    print("Blue White Red")
    if pos == 1:
      pos = 0
      sp = close
      print("Selling now at " + str(sp))
      pc = (sp/bp -1) * 100
      percentchange.append(pc)
  if (num == len(df) - 1) and (pos == 1):
    pos = 0
    sp = close
    print("Selling now at " + str(sp))
    pc = (sp/bp - 1) * 100
    percentchange.append(pc)

  num += 1

print(percentchange)




#   if df.loc[i, "Close"].values[0] > df.loc[i, smaString].values[0]:
#     print("The close is higher")
#     numH += 1
#   else:
#     print("The close is lower")
#     numC += 1

# print(str(numH))
# print(str(numC))
# Out:
# Red White Blue
# Buying now at Ticker
# MSFT    91.804253
# Name: 2019-01-03 00:00:00, dtype: float64
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at Ticker
# MSFT    96.89402
# Name: 2019-01-08 00:00:00, dtype: float64
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Red White Blue
# Buying now at Ticker
# MSFT    98.430374
# Name: 2019-01-31 00:00:00, dtype: float64
# Red White Blue
# Red White Blue
# Blue White Red
# Selling now at Ticker
# MSFT    101.060089
# Name: 2019-02-05 00:00:00, dtype: float64
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# Blue White Red
# ...

# %%
# ma = 50

# smaString = "Sma_" + str(ma)

# df[smaString] = df.iloc[:,4].rolling(window=ma).mean()

# df = df.iloc[ma:]

# print(df)

# %%
from re import A
gains = 0
ng = 0
losses = 0
nl = 0
totalR = 0

for i in percentchange:
  if(i.item()>0):
    gains += i.item()
    ng += 1
  else:
    losses += i.item()
    nl += 1
  totalR = totalR * ((i.item()/100)+1)
totalR = round((totalR-1)* 100,2)

if(ng>0):
  avgGain = gains/ng
  maxR = str(max([x.item() for x in percentchange]))
else:
  avgGain = 0
  maxR ="undefined"

if(nl>0):
  avgLoss = losses/nl
  maxL = str(min([x.item() for x in percentchange]))
  ratio = str(-avgGain/avgLoss)
else:
  avgLoss = 0
  maxL ="undefined"
  ratio = "inf"

if (ng> 0 or nl > 0):
  battingAvg = ng/(ng+nl)
else:
  battingAvg = 0


print()
print("Results for "+ stock +" going back to "+str(df.index[0])+", Sample size: "+str(ng+nl)+" trades")
print("EMAs used: "+str(emasUsed))
print("Batting Avg: "+ str(battingAvg))
print("Gain/loss ratio: "+ ratio)
print("Average Gain: "+ str(avgGain))
print("Average Loss: "+ str(avgLoss))
print("Max Return: "+ maxR)
print("Max Loss: "+ maxL)
print("Total return over "+str(ng+nl)+ " trades: "+ str(totalR)+"%" )
#print("Example return Simulating "+str(n)+ " trades: "+ str(nReturn)+"%" )
print()
# Out:
# Results for MSFT going back to 2019-01-02 00:00:00, Sample size: 81 trades
# EMAs used: [3, 5, 8, 10, 12, 15, 30, 35, 40, 45, 50, 60]
# Batting Avg: 0.6049382716049383
# Gain/loss ratio: 0.9329397571837159
# Average Gain: 2.384283120967188
# Average Loss: -2.555666754051378
# Max Return: 12.673787535021042
# Max Loss: -18.82659131225597
# Total return over 81 trades: -100.0%
